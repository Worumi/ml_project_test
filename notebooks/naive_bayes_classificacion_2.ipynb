# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import ConfusionMatrixDisplay, classification_report

sns.set_theme()

# %%
current_file = Path.cwd()
ROOT = current_file.parent.parent

data = pd.read_csv(f"{ROOT}/data/hipertension_arterial_ mexico_dataset/Hipertension_Arterial_Mexico.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 current_file = Path.cwd()
#       2 ROOT = current_file.parent.parent
#       3
# ----> 4 data = pd.read_csv(f"{ROOT}/data/hipertension_arterial_ mexico_dataset/Hipertension_Arterial_Mexico.csv")
#
# File ~/Documentos/proyectos/ml_project_test/.venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~/Documentos/proyectos/ml_project_test/.venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~/Documentos/proyectos/ml_project_test/.venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~/Documentos/proyectos/ml_project_test/.venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~/Documentos/proyectos/ml_project_test/.venv/lib/python3.14/site-packages/pandas/io/common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/alfredo/Documentos/proyectos/data/hipertension_arterial_ mexico_dataset/Hipertension_Arterial_Mexico.csv'

# %%
data.head()
# Out:
#          FOLIO_I  sexo  edad  concentracion_hemoglobina  temperatura_ambiente  \
# 0  2022_01001004     2    41                       14.2                    22
# 1  2022_01001009     2    65                       14.1                     9
# 2  2022_01001012     2    68                       14.2                    22
# 3  2022_01001013     1    35                       15.7                    11
# 4  2022_01001015     2    65                       12.7                     7
#
#    valor_acido_urico  valor_albumina  valor_colesterol_hdl  \
# 0                4.8             4.0                    34
# 1                4.4             3.8                    73
# 2                4.8             4.0                    34
# 3                6.5             4.1                    49
# 4                4.2             4.2                    41
#
#    valor_colesterol_ldl  valor_colesterol_total  ...  segundamedicion_peso  \
# 0                  86.0                     139  ...                 64.70
# 1                 130.0                     252  ...                 96.75
# 2                  86.0                     139  ...                 68.70
# 3                 107.0                     203  ...                 64.70
# 4                  76.0                     145  ...                 97.15
#
#    segundamedicion_estatura  distancia_rodilla_talon  \
# 0                     154.0                     48.5
# 1                     152.2                     44.5
# 2                     144.8                     42.3
# 3                     154.0                     48.5
# 4                     161.3                     49.6
#
#    circunferencia_de_la_pantorrilla  segundamedicion_cintura  \
# 0                              33.5                      0.0
# 1                              41.1                    113.7
# 2                              37.8                    103.7
# 3                              33.5                      0.0
# 4                              42.0                    118.9
#
#    tension_arterial  sueno_horas  masa_corporal  actividad_total  \
# 0               107            4      32.889389              120
# 1               104            2       1.000000              240
# 2               105            1       1.000000              480
# 3               117            5      26.265339              275
# 4               123            2       1.000000              255
#
#    riesgo_hipertension
# 0                    1
# 1                    0
# 2                    0
# 3                    1
# 4                    0
#
# [5 rows x 36 columns]

# %%
train_data, test_data = train_test_split(data, test_size=0.25, random_state=42, stratify=data["riesgo_hipertension"])

train_data: pd.DataFrame
test_data: pd.DataFrame

y_train = train_data["riesgo_hipertension"]
x_train = train_data.drop(columns=["FOLIO_I", "valor_colesterol_total", "riesgo_hipertension"])
y_test = test_data["riesgo_hipertension"]
x_test = test_data.drop(columns=["FOLIO_I", "valor_colesterol_total", "riesgo_hipertension"])

# %%
train_data["riesgo_hipertension"].value_counts(normalize=True)
# Out:
# riesgo_hipertension
# 1    0.645477
# 0    0.354523
# Name: proportion, dtype: float64

# %%
x_train.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 3272 entries, 191 to 2735
# Data columns (total 33 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   sexo                              3272 non-null   int64
#  1   edad                              3272 non-null   int64
#  2   concentracion_hemoglobina         3272 non-null   float64
#  3   temperatura_ambiente              3272 non-null   int64
#  4   valor_acido_urico                 3272 non-null   float64
#  5   valor_albumina                    3272 non-null   float64
#  6   valor_colesterol_hdl              3272 non-null   int64
#  7   valor_colesterol_ldl              3272 non-null   float64
#  8   valor_creatina                    3272 non-null   float64
#  9   resultado_glucosa                 3272 non-null   float64
#  10  valor_insulina                    3272 non-null   float64
#  11  valor_trigliceridos               3272 non-null   int64
#  12  resultado_glucosa_promedio        3272 non-null   int64
#  13  valor_hemoglobina_glucosilada     3272 non-null   float64
#  14  valor_ferritina                   3272 non-null   float64
#  15  valor_folato                      3272 non-null   float64
#  16  valor_homocisteina                3272 non-null   float64
#  17  valor_proteinac_reactiva          3272 non-null   float64
#  18  valor_transferrina                3272 non-null   float64
#  19  valor_vitamina_bdoce              3272 non-null   float64
#  20  valor_vitamina_d                  3272 non-null   float64
#  21  peso                              3272 non-null   float64
#  22  estatura                          3272 non-null   float64
#  23  medida_cintura                    3272 non-null   float64
#  24  segundamedicion_peso              3272 non-null   float64
#  25  segundamedicion_estatura          3272 non-null   float64
#  26  distancia_rodilla_talon           3272 non-null   float64
#  27  circunferencia_de_la_pantorrilla  3272 non-null   float64
#  28  segundamedicion_cintura           3272 non-null   float64
#  29  tension_arterial                  3272 non-null   int64
#  30  sueno_horas                       3272 non-null   int64
#  31  masa_corporal                     3272 non-null   float64
#  32  actividad_total                   3272 non-null   int64
# dtypes: float64(24), int64(9)
# memory usage: 869.1 KB

# %%
x_train["sexo"] = x_train["sexo"].astype("category")
x_test["sexo"] = x_test["sexo"].astype("category")

x_train.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 3272 entries, 191 to 2735
# Data columns (total 33 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   sexo                              3272 non-null   category
#  1   edad                              3272 non-null   int64
#  2   concentracion_hemoglobina         3272 non-null   float64
#  3   temperatura_ambiente              3272 non-null   int64
#  4   valor_acido_urico                 3272 non-null   float64
#  5   valor_albumina                    3272 non-null   float64
#  6   valor_colesterol_hdl              3272 non-null   int64
#  7   valor_colesterol_ldl              3272 non-null   float64
#  8   valor_creatina                    3272 non-null   float64
#  9   resultado_glucosa                 3272 non-null   float64
#  10  valor_insulina                    3272 non-null   float64
#  11  valor_trigliceridos               3272 non-null   int64
#  12  resultado_glucosa_promedio        3272 non-null   int64
#  13  valor_hemoglobina_glucosilada     3272 non-null   float64
#  14  valor_ferritina                   3272 non-null   float64
#  15  valor_folato                      3272 non-null   float64
#  16  valor_homocisteina                3272 non-null   float64
#  17  valor_proteinac_reactiva          3272 non-null   float64
#  18  valor_transferrina                3272 non-null   float64
#  19  valor_vitamina_bdoce              3272 non-null   float64
#  20  valor_vitamina_d                  3272 non-null   float64
#  21  peso                              3272 non-null   float64
#  22  estatura                          3272 non-null   float64
#  23  medida_cintura                    3272 non-null   float64
#  24  segundamedicion_peso              3272 non-null   float64
#  25  segundamedicion_estatura          3272 non-null   float64
#  26  distancia_rodilla_talon           3272 non-null   float64
#  27  circunferencia_de_la_pantorrilla  3272 non-null   float64
#  28  segundamedicion_cintura           3272 non-null   float64
#  29  tension_arterial                  3272 non-null   int64
#  30  sueno_horas                       3272 non-null   int64
#  31  masa_corporal                     3272 non-null   float64
#  32  actividad_total                   3272 non-null   int64
# dtypes: category(1), float64(24), int64(8)
# memory usage: 846.8 KB

# %%
numerical_columns = x_train.select_dtypes(["float64","Int64"]).columns.to_list()
categorical_columns = x_train.select_dtypes(["category"]).columns.to_list()

# %%
encoder = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numerical_columns),
        ("cat", OneHotEncoder(drop="first", sparse_output=False), categorical_columns)
    ]
)

encoder.set_output(transform="pandas")
# Out:
# ColumnTransformer(transformers=[('num', StandardScaler(),
#                                  ['edad', 'concentracion_hemoglobina',
#                                   'temperatura_ambiente', 'valor_acido_urico',
#                                   'valor_albumina', 'valor_colesterol_hdl',
#                                   'valor_colesterol_ldl', 'valor_creatina',
#                                   'resultado_glucosa', 'valor_insulina',
#                                   'valor_trigliceridos',
#                                   'resultado_glucosa_promedio',
#                                   'valor_hemoglobina_glucosilada',
#                                   'valor_ferritin...
#                                   'valor_proteinac_reactiva',
#                                   'valor_transferrina', 'valor_vitamina_bdoce',
#                                   'valor_vitamina_d', 'peso', 'estatura',
#                                   'medida_cintura', 'segundamedicion_peso',
#                                   'segundamedicion_estatura',
#                                   'distancia_rodilla_talon',
#                                   'circunferencia_de_la_pantorrilla',
#                                   'segundamedicion_cintura', 'tension_arterial',
#                                   'sueno_horas', ...]),
#                                 ('cat',
#                                  OneHotEncoder(drop='first',
#                                                sparse_output=False),
#                                  ['sexo'])])

# %%
x_train_encoded = encoder.fit_transform(x_train)

# %%
model = LogisticRegression().fit(x_train_encoded, y_train)

# %%
y_pred = model.predict(x_train_encoded)

# %%
print(classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.59      0.67      1160
#            1       0.80      0.90      0.85      2112
#
#     accuracy                           0.79      3272
#    macro avg       0.78      0.75      0.76      3272
# weighted avg       0.79      0.79      0.78      3272

# %%
ConfusionMatrixDisplay.from_predictions(y_train, y_pred)
plt.show()

# %%
pipeline = Pipeline(
    steps = [
        ("encoder", encoder),
        ("predictor", model)
    ]
)

# %%
y_pred_test = pipeline.predict(x_test)
print(classification_report(y_test, y_pred_test))
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.58      0.67       387
#            1       0.80      0.92      0.85       704
#
#     accuracy                           0.80      1091
#    macro avg       0.80      0.75      0.76      1091
# weighted avg       0.80      0.80      0.79      1091
